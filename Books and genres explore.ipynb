# %% [markdown]
# # 1st Capstone Notebook
# # Initial EDA of all datasets found
#
# This notebook contains my initial EDA of all the datasets I found online. I ended up only using the first two datasets in the project. Both datasets which were used came from Kaggle and together gave me title, full text, author, and publication year. Albeit the publication year is not the original publication year.
#
# ## EDA for books and genres dataset.
# Dataset came from Kaggle which contains full text data for Project Gutenberg books. It does not contain author or publication date. Origin: Kaggle https://www.kaggle.com/datasets/michaelrussell4/10000-books-and-their-genres-standardized

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_books_and_genres = pd.read_csv('~/OneDrive/Documents/BrainStation/Capstone/Downloaded datasets/books_and_genres.csv')

# %%
df_books_and_genres.head()
# Out:
#    Unnamed: 0                        title  \
# 0           0              apocolocyntosis
# 1           1  the house on the borderland
# 2           2                 the warriors
# 3           3         a voyage to the moon
# 4           4                 la fiammetta
#
#                                                 text  \
# 0  Produced by Ted Garvin, Ben Courtney and PG Di...
# 1  Produced by Suzanne Shell, Sjaani and PG Distr...
# 2  Produced by Charles Aldarondo, Charlie Kirschn...
# 3  Produced by Christine De Ryck, Stig M. Valstad...
# 4  Produced by Ted Garvin, Dave Morgan and PG Dis...
#
#                                               genres
# 0  {'21st-century', 'history', 'roman', 'classics...
# 1  {'horror', 'mystery', 'classics', 'science-fic...
# 2  {'literary-fiction', 'history', 'biography', '...
# 3  {'20th-century', 'science-fiction', 'speculati...
# 4  {'literary-fiction', 'history', 'feminism', 'c...

# %%
pd.options.display.max_colwidth=50

# %%
# find 'author' by searching for 'title' then after /n/n/ maybe? 
# Or maybe just join dataframes, which I need to do anyway for publication date

# %%
# Join https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html
# Probably best to drop unnecessary columns then join

# %%
df_books_and_genres['text'].head(10)
# Out:
# 0    Produced by Ted Garvin, Ben Courtney and PG Di...
# 1    Produced by Suzanne Shell, Sjaani and PG Distr...
# 2    Produced by Charles Aldarondo, Charlie Kirschn...
# 3    Produced by Christine De Ryck, Stig M. Valstad...
# 4    Produced by Ted Garvin, Dave Morgan and PG Dis...
# 5    Produced by Suzanne Shell, Sjaani and PG Distr...
# 6    Produced by Suzanne Shell, Danny Wool, Luiz An...
# 7    Produced by Beth Trapaga and PG Distributed Pr...
# 8    Produced by Imran Ghory, Stan Goodman, Josephi...
# 9    Produced by Suzanne Shell, Josephine Paolucci\...
# Name: text, dtype: object

# %%
df_books_and_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10635 entries, 0 to 10634
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10635 non-null  int64
#  1   title       10635 non-null  object
#  2   text        10373 non-null  object
#  3   genres      10635 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 332.5+ KB

# %%
df_books_and_genres.shape
# Out:
# (10635, 4)

# %%
df_books_and_genres['genres'].value_counts()
# Out:
# {'classics'}                                                                                                                                                                                                        171
# {'fiction'}                                                                                                                                                                                                         164
# {'history'}                                                                                                                                                                                                         118
# {'non-fiction'}                                                                                                                                                                                                      89
# ...

# %%
# I could use a loop to pull out every iteration of 'fiction' from the genre column.

# %%
def books(b):
    genre1 = []
    for g in b:
        genre1.append(g)
    return genre1

# %% [markdown]
# Function to make a list of the books, whose genre labels contain 'fiction'

# %%
fictions1 = []

def fiction_only(f):
    for s in f:
        if "fiction" in s:
            fictions1.append(s)
    return fictions1

# %%
# books(df_books_and_genres['genres'])
# print(genre1)

# %%
fiction_only(df_books_and_genres['genres'])
# Out:
# ["{'21st-century', 'history', 'roman', 'classics', 'religion', 'novels', 'philosophy', 'fiction', 'literature', 'short-stories', 'politics', 'non-fiction', 'read-for-school', 'poetry', 'historical', 'humor'}",
#  "{'horror', 'mystery', 'classics', 'science-fiction', 'fantasy', 'novels', 'literature', 'fiction', 'paranormal', '20th-century', 'adult', 'speculative-fiction', 'supernatural', 'dark'}",
#  "{'literary-fiction', 'history', 'biography', 'family', 'mythology', 'historical-fiction', 'non-fiction', 'historical', 'college', 'contemporary', 'high-school', 'fantasy', 'novels', 'literature', 'fiction', '20th-century', 'essays', 'school', 'adult', 'read-for-school', 'american', 'feminism', 'classics', 'short-stories', 'adult-fiction', 'memoir', 'coming-of-age'}",
#  "{'20th-century', 'science-fiction', 'speculative-fiction'}",
# ...

# %% [markdown]
# Number of books tagged with 'fiction' is 8,569

# %%
len(fictions1)
# Out:
# 8569

# %% [markdown]
# Function to make list of books tagged with '20th-century'

# %%
twentieth_century = []

def recent(f):
    for s in f:
        if '20th-century' in s:
            twentieth_century.append(s)
    return twentieth_century

# %%
recent(df_books_and_genres['genres'])
# Out:
# ["{'horror', 'mystery', 'classics', 'science-fiction', 'fantasy', 'novels', 'literature', 'fiction', 'paranormal', '20th-century', 'adult', 'speculative-fiction', 'supernatural', 'dark'}",
#  "{'literary-fiction', 'history', 'biography', 'family', 'mythology', 'historical-fiction', 'non-fiction', 'historical', 'college', 'contemporary', 'high-school', 'fantasy', 'novels', 'literature', 'fiction', '20th-century', 'essays', 'school', 'adult', 'read-for-school', 'american', 'feminism', 'classics', 'short-stories', 'adult-fiction', 'memoir', 'coming-of-age'}",
#  "{'20th-century', 'science-fiction', 'speculative-fiction'}",
#  "{'literary-fiction', 'history', 'feminism', 'classics', 'philosophy', 'fiction', 'literature', '20th-century', 'school', 'non-fiction', 'read-for-school', 'poetry', 'college'}",
# ...

# %% [markdown]
# Number of books tagged with 20th-century is 3,207

# %%
len(twentieth_century)
# Out:
# 3207

# %% [markdown]
# Dataframe of only books that are tagged with 'fiction' and '20th-century'. Contains 3,017 books.

# %%
books_wanted = pd.DataFrame()

books_wanted = df_books_and_genres.loc[df_books_and_genres["genres"].str.contains("20th-century") & df_books_and_genres["genres"].str.contains("fiction"), ["Unnamed: 0", "title", "text", "genres"]]

# %%
# Why isn't this 0 indexed?
books_wanted.head()
# Out:
#    Unnamed: 0                        title  \
# 1           1  the house on the borderland
# 2           2                 the warriors
# 3           3         a voyage to the moon
# 4           4                 la fiammetta
# 5           5                     carmilla
#
#                                                 text  \
# 1  Produced by Suzanne Shell, Sjaani and PG Distr...
# 2  Produced by Charles Aldarondo, Charlie Kirschn...
# 3  Produced by Christine De Ryck, Stig M. Valstad...
# 4  Produced by Ted Garvin, Dave Morgan and PG Dis...
# 5  Produced by Suzanne Shell, Sjaani and PG Distr...
#
#                                               genres
# 1  {'horror', 'mystery', 'classics', 'science-fic...
# 2  {'literary-fiction', 'history', 'biography', '...
# 3  {'20th-century', 'science-fiction', 'speculati...
# 4  {'literary-fiction', 'history', 'feminism', 'c...
# 5  {'romance', 'novella', 'historical-fiction', '...

# %%
books_wanted.shape
# Out:
# (3017, 4)

# %%
books_wanted['genres'].value_counts()
# Out:
# {'fiction', '20th-century'}                                                                                                                                                                                                                                                     15
# {'classics', 'fiction', '20th-century'}                                                                                                                                                                                                                                         12
# {'short-stories', '20th-century', 'science-fiction', 'fiction'}                                                                                                                                                                                                                 12
# ...

# %%
books_wanted.iloc[3]
# Out:
# Unnamed: 0                                                    4
# title                                              la fiammetta
# text          Produced by Ted Garvin, Dave Morgan and PG Dis...
# genres        {'literary-fiction', 'history', 'feminism', 'c...
# Name: 4, dtype: object

# %% [markdown]
# ## EDA of 2nd dataset of Amazon books
# This is another dataset which contains author and publication date, but no full text origin: Kaggle https://www.kaggle.com/datasets/saurabhbagchi/books-dataset

# %% [markdown]
# It contains a number of errors, hence the below code.

# %%
amazon_books = pd.read_csv('~/OneDrive/Documents/BrainStation/Capstone/Downloaded datasets/Books dataset (Amazon).csv', sep = ';', quotechar='"', error_bad_lines=False)
# Out:
# C:\Users\tanya\AppData\Local\Temp\ipykernel_9724\3103706455.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   amazon_books = pd.read_csv('~/OneDrive/Documents/BrainStation/Capstone/Downloaded datasets/Books dataset (Amazon).csv', sep = ';', quotechar='"', error_bad_lines=False)
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# ...

# %%
amazon_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
amazon_books.drop(columns=['Image-URL-S', 'Image-URL-M', 'Image-URL-L'], inplace=True)

# %%
amazon_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
amazon_books['Book-Title'] = amazon_books['Book-Title'].apply(str.lower)

# %%
amazon_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
# dtypes: object(5)
# memory usage: 10.4+ MB

# %%
amazon_books['Book-Author'] = amazon_books['Book-Author'].fillna('').apply(str.lower)

# %%
amazon_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                classical mythology
# 1  0002005018                                       clara callan
# 2  0060973129                               decision in normandy
# 3  0374157065  flu: the story of the great influenza pandemic...
# 4  0393045218                             the mummies of urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    mark p. o. morford                2002     Oxford University Press
# 1  richard bruce wright                2001       HarperFlamingo Canada
# 2          carlo d'este                1991             HarperPerennial
# 3      gina bari kolata                1999        Farrar Straus Giroux
# 4       e. j. w. barber                1999  W. W. Norton &amp; Company

# %% [markdown]
# Joining of first and second dataframes (the initial dataframe with full text and the Amazon dataframe with publication year and author)

# %%
books = df_books_and_genres.join(amazon_books.set_index('Book-Title'), on= 'title', how = 'inner')

# %%
books.sample(10)
# Out:
#       Unnamed: 0                       title  \
# 8278        8278           as a man thinketh
# 5129        5129                 the promise
# 8406        8406  rebecca of sunnybrook farm
# 5580        5580                  siddhartha
# 8817        8817               hide and seek
# 8686        8686             robinson crusoe
# 9086        9086          the created legend
# 975          975        the three musketeers
# 9698        9698                 bittersweet
# 5404        5404                      shiloh
#
#                                                    text  \
# 8278  Produced by Charles Aldarondo.  HTML version b...
# 5129  Produced by K. Nordquist, Barbara Tozier and t...
# 8406  Produced by Charles Keller.  HTML version by A...
# 5580  Produced by Michael Pullen,  Chandra Yenco, Is...
# 8817  Produced by James Rusk\n\n\n\n\n\nHIDE AND SEE...
# 8686  Produced by Bruce W. Miller\n\n\n\n\n\n\n\n\nR...
# 9086  Produced by Eric Eldred, Camilla Venezuela\nan...
# ...

# %%
books['Publication_year'] = pd.to_numeric(books['Year-Of-Publication'], errors='coerce')

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2741 entries, 1 to 10603
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           2741 non-null   int64
#  1   title                2741 non-null   object
#  2   text                 2741 non-null   object
#  3   genres               2741 non-null   object
#  4   ISBN                 2741 non-null   object
#  5   Book-Author          2741 non-null   object
#  6   Year-Of-Publication  2741 non-null   object
#  7   Publisher            2741 non-null   object
#  8   Publication_year     2741 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 214.1+ KB

# %%
books.to_csv('~/OneDrive/Documents/BrainStation/Capstone/final_books.csv')

# %%
books_non_zero = books[books['Publication_year'] != 0]

# %%
books_non_zero['Publication_year'].nsmallest(10,keep='last')
# Out:
# 8494    1920
# 3381    1920
# 1731    1921
# 8171    1922
# 5329    1938
# 2559    1940
# 8861    1942
# 7440    1942
# 9818    1946
# 8113    1950
# Name: Publication_year, dtype: int64

# %%
books.sort_values(by=['Publication_year'])
# Out:
#        Unnamed: 0                   title  \
# 10603       10603            wild animals
# 8275         8275    anne of green gables
# 8661         8661            wilhelm tell
# 9515         9515    der zerbrochene krug
# 2278         2278               jane eyre
# ...           ...                     ...
# 6231         6231         northern lights
# 6747         6747  the portrait of a lady
# 3759         3759                eventide
# 10363       10363               sanctuary
# 3985         3985                   heidi
#
#                                                     text  \
# 10603  Produced by Ralph Zimmermann, Charles Franks\n...
# 8275   Produced by Charles Keller\n\n\n\n\n\n        ...
# 8661   Produced by Tapio Riikonen and David Widger\n\...
# 9515   Thanks are given to Delphine Lettau for findin...
# 2278   Produced by Ebooks libres et gratuits; this te...
# ...                                                  ...
# ...

# %%
# a small number of ~100 rows had publication years of 0
books_zero = books[books['Year-Of-Publication']==0].index

# %%
# Dropping rows with publication year 0
# books.drop(books_zero, inplace=True)

# %%
books.shape
# Out:
# (2741, 9)

# %% [markdown]
# Weirdly when I changed the year of publication to an integer it didn't join but it did as a string.

# %% [markdown]
# Problem: At least some of these genres are inaccurate. For example, 'la fiammetta' is very old but the translation here is from the 20th century, so it's in the list. Goodreads was wrong.
#
# I may need a better way to categorized books. I might also need authors.

# %% [markdown]
# Problem: there are errors in some of the Amazon rows, I'll see if I can still join them and probably just ignore the errors for now. There aren't that many and I can fix them manually if needed.

# %% [markdown]
# ## EDA of third dataset
# This is another dataset which contains author and publication date, but no full text. Origin: Kaggle https://www.kaggle.com/datasets/zygmunt/goodbooks-10k?select=books.csv

# %%
goodbooks = pd.read_csv('~/OneDrive/Documents/BrainStation/Capstone/Downloaded datasets/goodbooks 10k.csv')

# %%
goodbooks.sample(5)
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 4507  4508     15096         15096  10730819           78    60958022
# 7527  7528  13282015      13282015  18486388           15  1468139339
# 6086  6087     16349         16349   6568307          188     7120699
# 5205  5206     13066         13066   2257006           31   446695688
# 5802  5803    263171        263171    255109           20    61132233
#
#             isbn13             authors  original_publication_year  \
# 4507  9.780061e+12       Joanne Harris                     2001.0
# 7527  9.781468e+12  Elisabeth Naughton                     2011.0
# 6086  9.780007e+12     Agatha Christie                     1938.0
# 5205  9.780447e+12        Carl Hiaasen                     2000.0
# 5802  9.780061e+12     Ellen Schreiber                     2007.0
#
#                                  original_title  ... ratings_count  \
# 4507                Five Quarters of the Orange  ...         23332
# ...

# %%
goodbooks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         10000 non-null  int64
#  1   book_id                    10000 non-null  int64
#  2   best_book_id               10000 non-null  int64
#  3   work_id                    10000 non-null  int64
#  4   books_count                10000 non-null  int64
#  5   isbn                       9300 non-null   object
#  6   isbn13                     9415 non-null   float64
#  7   authors                    10000 non-null  object
#  8   original_publication_year  9979 non-null   float64
#  9   original_title             9415 non-null   object
#  10  title                      10000 non-null  object
#  11  language_code              8916 non-null   object
#  12  average_rating             10000 non-null  float64
# ...

# %%
goodbooks.drop(goodbooks.iloc[:,11:], axis=1, inplace=True)

# %%
goodbooks.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %% [markdown]
# Looking at original publication year

# %%
goodbooks['original_publication_year'].nsmallest(20, keep='last')
# Out:
# 2075   -1750.0
# 2141    -762.0
# 6165    -750.0
# 340     -750.0
# 78      -720.0
# 1119    -560.0
# 9678    -500.0
# 5636    -500.0
# 402     -500.0
# 7777    -476.0
# 9280    -458.0
# 4148    -458.0
# 1520    -441.0
# 3403    -440.0
# 2762    -431.0
# 823     -430.0
# 4536    -411.0
# 4331    -411.0
# 2051    -401.0
# 4329    -400.0
# Name: original_publication_year, dtype: float64

# %%
filtered_goodbooks = goodbooks[goodbooks['original_publication_year']== -400.0]

# %%
filtered_goodbooks[['title', 'authors', 'original_publication_year']]
# Out:
#                                 title  \
# 2335                The Bhagavad Gita
# 4329  The Trial and Death of Socrates
#
#                                                 authors  \
# 2335  Krishna-Dwaipayana Vyasa, Simon Brodbeck, Juan...
# 4329                Plato, G.M.A. Grube, John M. Cooper
#
#       original_publication_year
# 2335                     -400.0
# 4329                     -400.0

# %%
goodbooks.shape
# Out:
# (10000, 11)

# %%
goodbooks.head(3)
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# 2                                  Twilight
#
#                                                title
# 0            The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2                            Twilight (Twilight, #1)

# %%
goodbooks['original_title'] = goodbooks['original_title'].fillna(' ').apply(str.lower)

# %%
goodbooks.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          the hunger games
# 1  harry potter and the philosopher's stone
# ...

# %%
# books = df_books_and_genres.join(amazon_books.set_index('Book-Title'), on= 'title', how = 'inner')

# %%
books_and_goodbooks = df_books_and_genres.join(goodbooks.set_index('original_title'), on = 'title', how = 'inner', lsuffix = '_left', rsuffix = 'good')

# %%
books_and_goodbooks.head()
# Out:
#                                  title  Unnamed: 0  \
# 5                             carmilla           5
# 31             the power and the glory          31
# 32                            paradise          32
# 60  the merry adventures of robin hood          60
# 83                       the professor          83
#
#                             title_left  \
# 5                             carmilla
# 31             the power and the glory
# 32                            paradise
# 60  the merry adventures of robin hood
# 83                       the professor
#
#                                                  text  \
# 5   Produced by Suzanne Shell, Sjaani and PG Distr...
# 31  Produced by Juliet Sutherland, Sjaani and PG D...
# 32  Produced by Judith Smith and Natalie Salter\n\...
# 60  Produced by Charles Keller and David Widger\n\...
# 83  Produced by An Anonymous Volunteer\n\n\n\n\n\n...
#
#                                                genres    id  book_id  \
# ...

# %%
books_and_goodbooks.shape
# Out:
# (261, 15)

# %% [markdown]
# Problem: my first join had a decent number of records but I'm unhappy with the veracity of the join and dates. My second join yields too few books.

# %%
amazon_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                classical mythology
# 1  0002005018                                       clara callan
# 2  0060973129                               decision in normandy
# 3  0374157065  flu: the story of the great influenza pandemic...
# 4  0393045218                             the mummies of urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    mark p. o. morford                2002     Oxford University Press
# 1  richard bruce wright                2001       HarperFlamingo Canada
# 2          carlo d'este                1991             HarperPerennial
# 3      gina bari kolata                1999        Farrar Straus Giroux
# 4       e. j. w. barber                1999  W. W. Norton &amp; Company

# %%
df_books_and_genres.head()
# Out:
#    Unnamed: 0                        title  \
# 0           0              apocolocyntosis
# 1           1  the house on the borderland
# 2           2                 the warriors
# 3           3         a voyage to the moon
# 4           4                 la fiammetta
#
#                                                 text  \
# 0  Produced by Ted Garvin, Ben Courtney and PG Di...
# 1  Produced by Suzanne Shell, Sjaani and PG Distr...
# 2  Produced by Charles Aldarondo, Charlie Kirschn...
# 3  Produced by Christine De Ryck, Stig M. Valstad...
# 4  Produced by Ted Garvin, Dave Morgan and PG Dis...
#
#                                               genres
# 0  {'21st-century', 'history', 'roman', 'classics...
# 1  {'horror', 'mystery', 'classics', 'science-fic...
# 2  {'literary-fiction', 'history', 'biography', '...
# 3  {'20th-century', 'science-fiction', 'speculati...
# 4  {'literary-fiction', 'history', 'feminism', 'c...

# %% [markdown]
# ## EDA of a fourth dataset
# After looking at the dataset, I discovered it did not contain the century in the publication date column, which made it rather useless as a dataset.

# %%
best_books = pd.read_csv("~/Downloads/books_1.Best_Books_Ever.csv")

# %%
pd.options.display.max_colwidth=50

# %%
best_books.head(3)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
# ...

# %%
best_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             50131 non-null  object
#  13  publisher         48782 non-null  object
#  14  publishDate       51598 non-null  object
#  15  firstPublishDate  31152 non-null  object
# ...

# %%
# Issue with best_books dataset: The publish years do not include the century.
